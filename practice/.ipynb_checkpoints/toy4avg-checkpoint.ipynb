# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pylab as plt

# %%
gal = np.array([[1,2,3], 
               [5,6,7]])
print(gal)
# Out:
# [[1 2 3]
#  [5 6 7]]

# %%
for z in range(2):
    gal

# %%
print(gal[:,0])
# Out:
# [1 5]
